# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Create Sample DATA

# %%
# Generate random data (house size in square feet and price)
np.random.seed(42) # Every time you run this script, it will produce the same random numbers.

house_size = np.random.randint(500, 4000, 50)
print("house_size: ", house_size)
print()

# .reshape(-1, 1): Reshapes the array into a column vector (50 rows, 1 column)
house_size_reshaped = house_size.reshape(-1, 1)
print("house_size_reshaped(first 5): \n", house_size_reshaped[:5])
print()

house_price = house_size_reshaped.flatten() * 50 + np.random.randint(20000, 70000, 50) # Target

# Convert to DataFrame for visualization
df = pd.DataFrame({"House Size (sq ft)": house_size_reshaped.flatten(), "House Price (€)":house_price})
print(df.head())
# Out:
# house_size:  [3674 1360 1794 1630 1595 3592 2138 2669  966 1738  830 1982 2635 3944
#  3671 3419  630 2185 3880 1269 2891 2015 3985 3353 2933 1715 1455 2824
#  1684  959 3885  521 2800 1247 3404  974 1582 3058 2547 3247 1475 2306
#   689 3505 3234 3505 1062 2399 1767 3379]
#
# house_size_reshaped(first 5):
#  [[3674]
#  [1360]
#  [1794]
#  [1630]
#  [1595]]
#
#    House Size (sq ft)  House Price (€)
# 0                3674           215094
# 1                1360            91556
# 2                1794           113590
# 3                1630           143106
# 4                1595           130490

# %% [markdown]
# #### Train a Machine Learning Model

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(house_size_reshaped, house_price, test_size=0.2, random_state=42)

# Create and train the Linear Regression model
model = LinearRegression()

# .fit(X_train, y_train): Trains the model by learning the relationship between house_size and house_price.
model.fit(X_train, y_train)

#Predict house prices
y_pred =model.predict(X_test)
print("X_test: \n", X_test)
print()
print("y_pred: \n",y_pred.reshape(-1, 1))
# Out:
# X_test:
#  [[3944]
#  [3247]
#  [3885]
#  [3505]
#  [2185]
#  [1767]
#  [1455]
#  [1715]
#  [2800]
#  [1269]]
#
# y_pred:
#  [[242451.83380442]
#  [205620.43084182]
#  [239334.11102853]
#  [219253.86264146]
#  [149501.42087585]
#  [127413.14765008]
#  [110926.20686912]
#  [124665.32418659]
#  [181999.71760756]
#  [101097.45371124]]

# %% [markdown]
# #### Visualizing the Model

# %%
# Plot the data points
plt.scatter(X_test, y_test, color='red', label='Actual Prices')
plt.scatter(X_test, y_pred, color='blue', label="Predicted Prices")
plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price ($)")
plt.title("House Price Prediction using Liner Regression")
plt.legend()
plt.show()
